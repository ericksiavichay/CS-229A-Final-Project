# %%
#!/usr/bin/env python3
import numpy as np
import math
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from keras.utils import to_categorical
from keras.utils import plot_model
import IPython.display
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# Out:
# Using TensorFlow backend.

# %%
#if i want to speed up and use one file
#files2 = "CSVLog_20190518_122417.csv"

#i aggregate the data points for five files into aggregate.csv. i have removed the time predictor from the data set
files = "aggregate_no_time_column.csv"

raw_dataset = pd.read_csv(files, sep=",", skipinitialspace=True)
dataset = raw_dataset.copy()

#remove whitespace in front of column name
dataset.columns = dataset.columns.str.lstrip()

# %%
dataset.tail()
# Out:
#       Absolute load value (%)  Absolute throttle position (%)  \
# 6633                 18.03922                        11.76471
# 6634                 17.64706                        11.76471
# 6635                 17.64706                        11.37255
# 6636                 17.25490                        11.37255
# 6637                 17.64706                        11.37255
#
#       Ambient air temperature (F)  Barometric pressure (inHg)  \
# 6633                         59.0                     29.8254
# 6634                         59.0                     29.8254
# 6635                         59.0                     29.8254
# 6636                         59.0                     29.8254
# 6637                         59.0                     29.8254
#
#       Calculated load value (%)  Commanded fuel rail pressure A (inHg)  \
# 6633                   29.01961                                885.903
# 6634                   29.01961                                885.903
# 6635                   29.41176                                885.903
# 6636                   29.41176                                885.903
# 6637                   29.80392                                885.903
#
#       Engine coolant temperature (F)  Engine RPM (RPM)  Fuel level input (%)  \
# 6633                           183.2            658.75              67.05882
# 6634                           183.2            640.00              67.05882
# 6635                           183.2            607.75              67.05882
# 6636                           183.2            606.75              67.05882
# 6637                           183.2            604.50              67.05882
#
#       Fuel rail pressure (psi)  Fuel/Air commanded equivalence ratio  \
# 6633                  424.9606                              0.994239
# 6634                  449.6170                              0.994239
# 6635                  429.3117                              0.994239
# 6636                  449.6170                              0.994239
# 6637                  429.3117                              0.994239
#
#       Ignition timing advance for #1 cylinder (deg)  \
# 6633                                            5.0
# 6634                                            4.5
# 6635                                            4.0
# 6636                                            6.5
# 6637                                            6.0
#
#       Intake air temperature (F)  Intake manifold absolute pressure (inHg)  \
# 6633                        71.6                                  11.51674
# 6634                        71.6                                  11.51674
# 6635                        71.6                                  11.51674
# 6636                        71.6                                  11.51674
# 6637                        71.6                                  11.51674
#
#       Long term fuel % trim - Bank 1 (%)  Mass air flow rate (lb/min)  \
# 6633                            -0.78125                     0.308259
# 6634                            -0.78125                     0.257985
# 6635                            -0.78125                     0.325458
# 6636                            -0.78125                     0.239463
# 6637                            -0.78125                     0.227556
#
#       Vehicle speed (MPH)  Fuel rate (gal/hr)  Instant fuel economy (MPG)  \
# 6633                  0.0            0.205909                         0.0
# 6634                  0.0            0.172327                         0.0
# 6635                  0.0            0.217398                         0.0
# 6636                  0.0            0.159955                         0.0
# 6637                  0.0            0.152002                         0.0
#
#       Total fuel economy (MPG)
# 6633                  30.11613
# 6634                  30.11534
# 6635                  30.11455
# 6636                  30.11384
# 6637                  30.11316

# %%
# %%time 
#set seed here!

#creating data and splitting and random shuffling
#https://stackoverflow.com/questions/38250710/how-to-split-data-into-3-sets-train-validation-and-test/38251213#38251213
def train_validate_test_split(df, train_percent=.6, validate_percent=.2, seed=None):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    train = df.loc[perm[:train_end]]
    validate = df.loc[perm[train_end:validate_end]]
    test = df.loc[perm[validate_end:]]
    return train, validate, test

np.random.seed(88)
train, validate, test = train_validate_test_split(dataset)

train_labels = train.pop("Total fuel economy (MPG)")
validate_labels = validate.pop("Total fuel economy (MPG)")
test_labels = test.pop("Total fuel economy (MPG)")
# Out:
# CPU times: user 5.16 ms, sys: 4.98 ms, total: 10.1 ms
# Wall time: 8.53 ms

# %%
#test_labels
#train.dtypes

# %%
train = train.apply(lambda col:pd.to_numeric(col, errors='coerce'))
train_stats = train.describe(include = 'all')
#train_stats = train.transpose()
train_stats
# Out:
#        Absolute load value (%)  Absolute throttle position (%)  \
# count              3982.000000                     3982.000000
# mean                 34.853803                       21.319566
# std                  24.330473                       13.733832
# min                   0.000000                        0.000000
# 25%                  16.078430                       12.156860
# 50%                  24.901960                       15.294120
# 75%                  49.411770                       27.058820
# max                  99.215680                       90.980390
#
#        Ambient air temperature (F)  Barometric pressure (inHg)  \
# count                  3982.000000                 3982.000000
# mean                     67.441135                   29.719798
# std                      12.373361                    0.693858
# min                       0.000000                    0.000000
# 25%                      62.600000                   29.530100
# 50%                      62.600000                   29.825400
# 75%                      64.400000                   29.825400
# max                     118.400000                   30.120700
#
#        Calculated load value (%)  Commanded fuel rail pressure A (inHg)  \
# count                3982.000000                            3982.000000
# mean                   42.614510                            1847.825637
# std                    26.139352                            1164.708580
# min                     0.000000                               0.000000
# 25%                    20.784310                             885.903000
# 50%                    38.431370                            1218.116500
# 75%                    56.862740                            2586.098750
# max                   100.000000                            5906.020000
#
#        Engine coolant temperature (F)  Engine RPM (RPM)  Fuel level input (%)  \
# count                     3982.000000       3982.000000           3982.000000
# mean                       185.527725       1509.206115             74.657725
# std                          8.289201        640.742896             10.979784
# min                          0.000000          0.000000              0.000000
# 25%                        183.200000       1064.000000             67.450980
# 50%                        185.000000       1476.000000             74.509800
# 75%                        188.600000       1984.125000             81.176470
# max                        204.800000       4474.500000             93.333340
#
#        Fuel rail pressure (psi)  Fuel/Air commanded equivalence ratio  \
# count               3982.000000                           3982.000000
# mean                 921.582978                              0.981455
# std                  564.071174                              0.035282
# min                    0.000000                              0.000000
# 25%                  478.624500                              0.990426
# 50%                  620.036350                              0.993202
# 75%                 1267.630000                              0.995520
# max                 2987.777000                              1.016260
#
#        Ignition timing advance for #1 cylinder (deg)  \
# count                                    3982.000000
# mean                                       21.216349
# std                                        15.302430
# min                                       -11.000000
# 25%                                         4.500000
# 50%                                        24.000000
# 75%                                        35.500000
# max                                        47.500000
#
#        Intake air temperature (F)  Intake manifold absolute pressure (inHg)  \
# count                 3982.000000                               3982.000000
# mean                    73.180964                                 17.617501
# std                     13.794495                                  8.796498
# min                      0.000000                                  0.000000
# 25%                     64.400000                                 10.040230
# 50%                     68.000000                                 15.060350
# 75%                     77.000000                                 27.167690
# max                    122.000000                                 30.711300
#
#        Long term fuel % trim - Bank 1 (%)  Mass air flow rate (lb/min)  \
# count                         3982.000000                  3982.000000
# mean                             5.407145                     1.486404
# std                              3.918990                     1.549543
# min                             -2.343750                     0.000000
# 25%                              2.343750                     0.313551
# 50%                              6.250000                     0.810338
# 75%                              7.812500                     2.250092
# max                             12.500000                    11.959920
#
#        Vehicle speed (MPH)  Fuel rate (gal/hr)  Instant fuel economy (MPG)
# count          3982.000000         3982.000000                 3982.000000
# mean             31.653728            1.004254                   61.219126
# std              22.873595            1.043080                   80.515170
# min               0.000000            0.000000                    0.000000
# 25%              10.563310            0.211751                   11.717023
# 50%              31.068560            0.551700                   32.498315
# 75%              47.224210            1.519516                   82.960725
# max              76.428660            8.026347                 1252.727000

# %%
type(train_stats)
# Out:
# pandas.core.frame.DataFrame

# %%
#https://stackoverflow.com/questions/40758562/can-anyone-explain-me-standardscaler
scaler = StandardScaler()
normed_train = scaler.fit_transform(train)
normed_validate = scaler.fit_transform(validate)
normed_test = scaler.fit_transform(test)

#not technically correct
#from tf regression website
#Note: Although we intentionally generate these statistics from only the training dataset, 
#these statistics will also be used to normalize the test dataset. We need to do that to project the test 
#dataset into the same distribution that the model has been trained on.

#I normalize it according to the mean and sd of each predictor from each set instead of normalizaing from 
#training set only

# %%
#debugging
#normed_train

# %%
def build_model_A():
  model = keras.Sequential([
    layers.Dense(5, activation=tf.nn.relu, input_shape=[len(train.keys())]),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mean_squared_error',
                optimizer=optimizer,
                metrics=['mean_absolute_error', 'mean_squared_error'])
  return model

def build_model_B():
  model = keras.Sequential([
    layers.Dense(20, activation=tf.nn.relu, input_shape=[len(train.keys())]),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mean_squared_error',
                optimizer=optimizer,
                metrics=['mean_absolute_error', 'mean_squared_error'])
  return model

# %%
# %%time
model_A = build_model_A()
model_A.summary()
model_B = build_model_B()
model_B.summary()
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 100
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 106
# Trainable params: 106
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 20)                400
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 421
# Trainable params: 421
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: user 279 ms, sys: 17 ms, total: 296 ms
# Wall time: 293 ms

# %%
# %%time
#change batch size?
#try early stop?
# The patience parameter is the amount of epochs to check for improvement
#early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

#history_object = model.fit(train, train_labels, epochs=100, verbose=2,
#         validation_data=(validate, validate_labels), callbacks=[early_stop])

history_object_A = model_A.fit(normed_train, train_labels, epochs=50, verbose=2,
         validation_data=(normed_validate, validate_labels))
# Out:
# Train on 3982 samples, validate on 1327 samples
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
#  - 0s - loss: 833.6221 - mean_absolute_error: 28.6870 - mean_squared_error: 833.6223 - val_loss: 807.4863 - val_mean_absolute_error: 28.2193 - val_mean_squared_error: 807.4863
# Epoch 2/50
#  - 0s - loss: 784.5615 - mean_absolute_error: 27.8038 - mean_squared_error: 784.5614 - val_loss: 757.5747 - val_mean_absolute_error: 27.2988 - val_mean_squared_error: 757.5746
# Epoch 3/50
#  - 0s - loss: 730.5354 - mean_absolute_error: 26.7763 - mean_squared_error: 730.5353 - val_loss: 698.7431 - val_mean_absolute_error: 26.1529 - val_mean_squared_error: 698.7431
# Epoch 4/50
#  - 0s - loss: 664.3796 - mean_absolute_error: 25.4451 - mean_squared_error: 664.3796 - val_loss: 623.7927 - val_mean_absolute_error: 24.5996 - val_mean_squared_error: 623.7928
# Epoch 5/50
#  - 0s - loss: 580.8753 - mean_absolute_error: 23.6271 - mean_squared_error: 580.8753 - val_loss: 532.3362 - val_mean_absolute_error: 22.5102 - val_mean_squared_error: 532.3361
# Epoch 6/50
#  - 0s - loss: 484.3861 - mean_absolute_error: 21.2785 - mean_squared_error: 484.3860 - val_loss: 432.4173 - val_mean_absolute_error: 19.9119 - val_mean_squared_error: 432.4172
# Epoch 7/50
#  - 0s - loss: 384.5612 - mean_absolute_error: 18.4951 - mean_squared_error: 384.5612 - val_loss: 335.3945 - val_mean_absolute_error: 17.0048 - val_mean_squared_error: 335.3945
# Epoch 8/50
#  - 0s - loss: 292.8302 - mean_absolute_error: 15.7113 - mean_squared_error: 292.8301 - val_loss: 252.0350 - val_mean_absolute_error: 14.4546 - val_mean_squared_error: 252.0350
# Epoch 9/50
#  - 0s - loss: 217.0804 - mean_absolute_error: 13.2673 - mean_squared_error: 217.0804 - val_loss: 184.1042 - val_mean_absolute_error: 12.0700 - val_mean_squared_error: 184.1042
# Epoch 10/50
#  - 0s - loss: 156.6496 - mean_absolute_error: 10.8740 - mean_squared_error: 156.6496 - val_loss: 129.7498 - val_mean_absolute_error: 9.6314 - val_mean_squared_error: 129.7498
# Epoch 11/50
#  - 0s - loss: 113.4557 - mean_absolute_error: 8.8228 - mean_squared_error: 113.4557 - val_loss: 94.3431 - val_mean_absolute_error: 7.8523 - val_mean_squared_error: 94.3431
# Epoch 12/50
#  - 0s - loss: 88.9672 - mean_absolute_error: 7.5780 - mean_squared_error: 88.9672 - val_loss: 76.0978 - val_mean_absolute_error: 6.8883 - val_mean_squared_error: 76.0978
# Epoch 13/50
#  - 0s - loss: 75.5393 - mean_absolute_error: 6.8886 - mean_squared_error: 75.5393 - val_loss: 64.6823 - val_mean_absolute_error: 6.2762 - val_mean_squared_error: 64.6823
# Epoch 14/50
#  - 0s - loss: 64.0259 - mean_absolute_error: 6.2660 - mean_squared_error: 64.0259 - val_loss: 54.2420 - val_mean_absolute_error: 5.6793 - val_mean_squared_error: 54.2420
# Epoch 15/50
#  - 0s - loss: 53.6509 - mean_absolute_error: 5.6483 - mean_squared_error: 53.6509 - val_loss: 44.7608 - val_mean_absolute_error: 5.0912 - val_mean_squared_error: 44.7608
# Epoch 16/50
#  - 0s - loss: 44.3151 - mean_absolute_error: 5.0501 - mean_squared_error: 44.3151 - val_loss: 36.8880 - val_mean_absolute_error: 4.5511 - val_mean_squared_error: 36.8880
# Epoch 17/50
#  - 0s - loss: 37.0223 - mean_absolute_error: 4.5290 - mean_squared_error: 37.0224 - val_loss: 30.7543 - val_mean_absolute_error: 4.1304 - val_mean_squared_error: 30.7543
# Epoch 18/50
#  - 0s - loss: 31.2762 - mean_absolute_error: 4.1190 - mean_squared_error: 31.2762 - val_loss: 25.9249 - val_mean_absolute_error: 3.8012 - val_mean_squared_error: 25.9249
# Epoch 19/50
#  - 0s - loss: 27.0599 - mean_absolute_error: 3.7880 - mean_squared_error: 27.0599 - val_loss: 22.5707 - val_mean_absolute_error: 3.5913 - val_mean_squared_error: 22.5707
# Epoch 20/50
#  - 0s - loss: 23.7170 - mean_absolute_error: 3.5548 - mean_squared_error: 23.7170 - val_loss: 19.5454 - val_mean_absolute_error: 3.3540 - val_mean_squared_error: 19.5454
# Epoch 21/50
#  - 0s - loss: 21.1008 - mean_absolute_error: 3.3519 - mean_squared_error: 21.1008 - val_loss: 17.6547 - val_mean_absolute_error: 3.2083 - val_mean_squared_error: 17.6547
# Epoch 22/50
#  - 0s - loss: 19.0876 - mean_absolute_error: 3.1901 - mean_squared_error: 19.0876 - val_loss: 16.0498 - val_mean_absolute_error: 3.0567 - val_mean_squared_error: 16.0498
# Epoch 23/50
#  - 0s - loss: 17.4900 - mean_absolute_error: 3.0451 - mean_squared_error: 17.4900 - val_loss: 14.6461 - val_mean_absolute_error: 2.9017 - val_mean_squared_error: 14.6461
# Epoch 24/50
#  - 0s - loss: 16.2254 - mean_absolute_error: 2.9188 - mean_squared_error: 16.2254 - val_loss: 13.9133 - val_mean_absolute_error: 2.8318 - val_mean_squared_error: 13.9133
# Epoch 25/50
#  - 0s - loss: 14.9914 - mean_absolute_error: 2.8090 - mean_squared_error: 14.9914 - val_loss: 12.8337 - val_mean_absolute_error: 2.7134 - val_mean_squared_error: 12.8337
# Epoch 26/50
#  - 0s - loss: 13.8856 - mean_absolute_error: 2.7018 - mean_squared_error: 13.8856 - val_loss: 11.9335 - val_mean_absolute_error: 2.6012 - val_mean_squared_error: 11.9335
# Epoch 27/50
#  - 0s - loss: 12.9389 - mean_absolute_error: 2.6081 - mean_squared_error: 12.9389 - val_loss: 11.2616 - val_mean_absolute_error: 2.5286 - val_mean_squared_error: 11.2616
# Epoch 28/50
#  - 0s - loss: 12.1977 - mean_absolute_error: 2.5355 - mean_squared_error: 12.1977 - val_loss: 10.7296 - val_mean_absolute_error: 2.4692 - val_mean_squared_error: 10.7296
# Epoch 29/50
#  - 0s - loss: 11.5765 - mean_absolute_error: 2.4695 - mean_squared_error: 11.5765 - val_loss: 10.1982 - val_mean_absolute_error: 2.4009 - val_mean_squared_error: 10.1982
# Epoch 30/50
#  - 0s - loss: 11.0021 - mean_absolute_error: 2.4189 - mean_squared_error: 11.0021 - val_loss: 9.6661 - val_mean_absolute_error: 2.3355 - val_mean_squared_error: 9.6661
# Epoch 31/50
#  - 0s - loss: 10.5008 - mean_absolute_error: 2.3725 - mean_squared_error: 10.5008 - val_loss: 9.3488 - val_mean_absolute_error: 2.3083 - val_mean_squared_error: 9.3488
# Epoch 32/50
#  - 0s - loss: 10.1154 - mean_absolute_error: 2.3292 - mean_squared_error: 10.1154 - val_loss: 9.0354 - val_mean_absolute_error: 2.2684 - val_mean_squared_error: 9.0354
# Epoch 33/50
#  - 0s - loss: 9.7218 - mean_absolute_error: 2.2914 - mean_squared_error: 9.7218 - val_loss: 8.7273 - val_mean_absolute_error: 2.2295 - val_mean_squared_error: 8.7273
# Epoch 34/50
#  - 0s - loss: 9.4080 - mean_absolute_error: 2.2567 - mean_squared_error: 9.4080 - val_loss: 8.5130 - val_mean_absolute_error: 2.2007 - val_mean_squared_error: 8.5130
# Epoch 35/50
#  - 0s - loss: 9.1151 - mean_absolute_error: 2.2319 - mean_squared_error: 9.1151 - val_loss: 8.3012 - val_mean_absolute_error: 2.1637 - val_mean_squared_error: 8.3012
# Epoch 36/50
#  - 0s - loss: 8.9015 - mean_absolute_error: 2.2038 - mean_squared_error: 8.9015 - val_loss: 8.2098 - val_mean_absolute_error: 2.1560 - val_mean_squared_error: 8.2098
# Epoch 37/50
#  - 0s - loss: 8.7006 - mean_absolute_error: 2.1859 - mean_squared_error: 8.7006 - val_loss: 8.0539 - val_mean_absolute_error: 2.1391 - val_mean_squared_error: 8.0539
# Epoch 38/50
#  - 0s - loss: 8.5660 - mean_absolute_error: 2.1686 - mean_squared_error: 8.5660 - val_loss: 7.9747 - val_mean_absolute_error: 2.1169 - val_mean_squared_error: 7.9747
# Epoch 39/50
#  - 0s - loss: 8.4407 - mean_absolute_error: 2.1516 - mean_squared_error: 8.4407 - val_loss: 7.8975 - val_mean_absolute_error: 2.1102 - val_mean_squared_error: 7.8975
# Epoch 40/50
#  - 0s - loss: 8.3061 - mean_absolute_error: 2.1385 - mean_squared_error: 8.3061 - val_loss: 7.7653 - val_mean_absolute_error: 2.0861 - val_mean_squared_error: 7.7653
# Epoch 41/50
#  - 0s - loss: 8.1834 - mean_absolute_error: 2.1236 - mean_squared_error: 8.1834 - val_loss: 7.7600 - val_mean_absolute_error: 2.0898 - val_mean_squared_error: 7.7600
# Epoch 42/50
#  - 0s - loss: 8.0449 - mean_absolute_error: 2.1080 - mean_squared_error: 8.0449 - val_loss: 7.6434 - val_mean_absolute_error: 2.0766 - val_mean_squared_error: 7.6434
# Epoch 43/50
#  - 0s - loss: 7.9073 - mean_absolute_error: 2.0907 - mean_squared_error: 7.9073 - val_loss: 7.7007 - val_mean_absolute_error: 2.0983 - val_mean_squared_error: 7.7007
# Epoch 44/50
#  - 0s - loss: 7.7946 - mean_absolute_error: 2.0827 - mean_squared_error: 7.7946 - val_loss: 7.4511 - val_mean_absolute_error: 2.0506 - val_mean_squared_error: 7.4511
# Epoch 45/50
#  - 0s - loss: 7.6928 - mean_absolute_error: 2.0670 - mean_squared_error: 7.6928 - val_loss: 7.4363 - val_mean_absolute_error: 2.0523 - val_mean_squared_error: 7.4363
# Epoch 46/50
#  - 0s - loss: 7.6019 - mean_absolute_error: 2.0566 - mean_squared_error: 7.6019 - val_loss: 7.3361 - val_mean_absolute_error: 2.0286 - val_mean_squared_error: 7.3361
# Epoch 47/50
#  - 0s - loss: 7.4789 - mean_absolute_error: 2.0399 - mean_squared_error: 7.4789 - val_loss: 7.3162 - val_mean_absolute_error: 2.0266 - val_mean_squared_error: 7.3162
# Epoch 48/50
#  - 0s - loss: 7.3616 - mean_absolute_error: 2.0297 - mean_squared_error: 7.3616 - val_loss: 7.1971 - val_mean_absolute_error: 2.0190 - val_mean_squared_error: 7.1971
# Epoch 49/50
#  - 0s - loss: 7.2641 - mean_absolute_error: 2.0178 - mean_squared_error: 7.2641 - val_loss: 7.1518 - val_mean_absolute_error: 2.0088 - val_mean_squared_error: 7.1518
# Epoch 50/50
#  - 0s - loss: 7.1603 - mean_absolute_error: 2.0059 - mean_squared_error: 7.1603 - val_loss: 7.0430 - val_mean_absolute_error: 1.9858 - val_mean_squared_error: 7.0430
# CPU times: user 10.9 s, sys: 3.27 s, total: 14.2 s
# Wall time: 6.9 s

# %%
# %%time
history_object_B = model_B.fit(normed_train, train_labels, epochs=50, verbose=2,
         validation_data=(normed_validate, validate_labels))
# Out:
# Train on 3982 samples, validate on 1327 samples
# Epoch 1/50
#  - 0s - loss: 767.2498 - mean_absolute_error: 27.4791 - mean_squared_error: 767.2499 - val_loss: 679.9619 - val_mean_absolute_error: 25.8413 - val_mean_squared_error: 679.9618
# Epoch 2/50
#  - 0s - loss: 579.8198 - mean_absolute_error: 23.7372 - mean_squared_error: 579.8198 - val_loss: 477.0019 - val_mean_absolute_error: 21.4192 - val_mean_squared_error: 477.0020
# Epoch 3/50
#  - 0s - loss: 372.2532 - mean_absolute_error: 18.5134 - mean_squared_error: 372.2533 - val_loss: 273.1120 - val_mean_absolute_error: 15.4459 - val_mean_squared_error: 273.1120
# Epoch 4/50
#  - 0s - loss: 198.5533 - mean_absolute_error: 12.2984 - mean_squared_error: 198.5533 - val_loss: 136.1572 - val_mean_absolute_error: 9.5566 - val_mean_squared_error: 136.1572
# Epoch 5/50
#  - 0s - loss: 114.7884 - mean_absolute_error: 8.4606 - mean_squared_error: 114.7883 - val_loss: 93.0627 - val_mean_absolute_error: 7.4600 - val_mean_squared_error: 93.0627
# Epoch 6/50
#  - 0s - loss: 87.5419 - mean_absolute_error: 7.1789 - mean_squared_error: 87.5419 - val_loss: 71.6016 - val_mean_absolute_error: 6.3910 - val_mean_squared_error: 71.6016
# Epoch 7/50
#  - 0s - loss: 67.4450 - mean_absolute_error: 6.1196 - mean_squared_error: 67.4450 - val_loss: 54.6675 - val_mean_absolute_error: 5.5220 - val_mean_squared_error: 54.6675
# Epoch 8/50
#  - 0s - loss: 51.8212 - mean_absolute_error: 5.2640 - mean_squared_error: 51.8212 - val_loss: 41.0784 - val_mean_absolute_error: 4.7295 - val_mean_squared_error: 41.0785
# Epoch 9/50
#  - 0s - loss: 39.3909 - mean_absolute_error: 4.5123 - mean_squared_error: 39.3909 - val_loss: 30.5530 - val_mean_absolute_error: 4.0862 - val_mean_squared_error: 30.5530
# Epoch 10/50
#  - 0s - loss: 29.9937 - mean_absolute_error: 3.8784 - mean_squared_error: 29.9937 - val_loss: 22.7540 - val_mean_absolute_error: 3.5778 - val_mean_squared_error: 22.7540
# Epoch 11/50
#  - 0s - loss: 22.9855 - mean_absolute_error: 3.3806 - mean_squared_error: 22.9855 - val_loss: 16.8850 - val_mean_absolute_error: 3.1432 - val_mean_squared_error: 16.8850
# Epoch 12/50
#  - 0s - loss: 17.9665 - mean_absolute_error: 2.9717 - mean_squared_error: 17.9665 - val_loss: 12.8722 - val_mean_absolute_error: 2.7701 - val_mean_squared_error: 12.8722
# Epoch 13/50
#  - 0s - loss: 14.6755 - mean_absolute_error: 2.6695 - mean_squared_error: 14.6754 - val_loss: 10.2055 - val_mean_absolute_error: 2.4436 - val_mean_squared_error: 10.2055
# Epoch 14/50
#  - 0s - loss: 12.3965 - mean_absolute_error: 2.4434 - mean_squared_error: 12.3965 - val_loss: 8.7571 - val_mean_absolute_error: 2.2936 - val_mean_squared_error: 8.7571
# Epoch 15/50
#  - 0s - loss: 10.9156 - mean_absolute_error: 2.2833 - mean_squared_error: 10.9156 - val_loss: 7.8467 - val_mean_absolute_error: 2.1759 - val_mean_squared_error: 7.8467
# Epoch 16/50
#  - 0s - loss: 9.9422 - mean_absolute_error: 2.1650 - mean_squared_error: 9.9422 - val_loss: 6.8606 - val_mean_absolute_error: 2.0107 - val_mean_squared_error: 6.8606
# Epoch 17/50
#  - 0s - loss: 8.9721 - mean_absolute_error: 2.0418 - mean_squared_error: 8.9721 - val_loss: 6.2988 - val_mean_absolute_error: 1.9278 - val_mean_squared_error: 6.2988
# Epoch 18/50
#  - 0s - loss: 8.1779 - mean_absolute_error: 1.9380 - mean_squared_error: 8.1779 - val_loss: 6.0028 - val_mean_absolute_error: 1.8630 - val_mean_squared_error: 6.0028
# Epoch 19/50
#  - 0s - loss: 7.5523 - mean_absolute_error: 1.8449 - mean_squared_error: 7.5523 - val_loss: 5.4758 - val_mean_absolute_error: 1.7689 - val_mean_squared_error: 5.4758
# Epoch 20/50
#  - 0s - loss: 7.0636 - mean_absolute_error: 1.7703 - mean_squared_error: 7.0636 - val_loss: 5.1016 - val_mean_absolute_error: 1.7077 - val_mean_squared_error: 5.1016
# Epoch 21/50
#  - 0s - loss: 6.6140 - mean_absolute_error: 1.6979 - mean_squared_error: 6.6140 - val_loss: 4.8015 - val_mean_absolute_error: 1.6633 - val_mean_squared_error: 4.8015
# Epoch 22/50
#  - 0s - loss: 6.2563 - mean_absolute_error: 1.6353 - mean_squared_error: 6.2563 - val_loss: 4.5744 - val_mean_absolute_error: 1.5926 - val_mean_squared_error: 4.5744
# Epoch 23/50
#  - 0s - loss: 5.9193 - mean_absolute_error: 1.5833 - mean_squared_error: 5.9193 - val_loss: 4.3288 - val_mean_absolute_error: 1.5543 - val_mean_squared_error: 4.3288
# Epoch 24/50
#  - 0s - loss: 5.5622 - mean_absolute_error: 1.5385 - mean_squared_error: 5.5622 - val_loss: 4.2780 - val_mean_absolute_error: 1.5416 - val_mean_squared_error: 4.2780
# Epoch 25/50
#  - 0s - loss: 5.3082 - mean_absolute_error: 1.5008 - mean_squared_error: 5.3082 - val_loss: 4.0558 - val_mean_absolute_error: 1.4697 - val_mean_squared_error: 4.0558
# Epoch 26/50
#  - 0s - loss: 5.1801 - mean_absolute_error: 1.4635 - mean_squared_error: 5.1801 - val_loss: 3.9453 - val_mean_absolute_error: 1.4512 - val_mean_squared_error: 3.9453
# Epoch 27/50
#  - 0s - loss: 4.9667 - mean_absolute_error: 1.4299 - mean_squared_error: 4.9667 - val_loss: 3.8071 - val_mean_absolute_error: 1.4026 - val_mean_squared_error: 3.8071
# Epoch 28/50
#  - 0s - loss: 4.7969 - mean_absolute_error: 1.4008 - mean_squared_error: 4.7969 - val_loss: 3.9155 - val_mean_absolute_error: 1.4435 - val_mean_squared_error: 3.9155
# Epoch 29/50
#  - 0s - loss: 4.6261 - mean_absolute_error: 1.3690 - mean_squared_error: 4.6261 - val_loss: 3.5677 - val_mean_absolute_error: 1.3608 - val_mean_squared_error: 3.5677
# Epoch 30/50
#  - 0s - loss: 4.4485 - mean_absolute_error: 1.3486 - mean_squared_error: 4.4485 - val_loss: 3.5825 - val_mean_absolute_error: 1.3798 - val_mean_squared_error: 3.5825
# Epoch 31/50
#  - 0s - loss: 4.3628 - mean_absolute_error: 1.3221 - mean_squared_error: 4.3628 - val_loss: 3.5320 - val_mean_absolute_error: 1.3495 - val_mean_squared_error: 3.5320
# Epoch 32/50
#  - 0s - loss: 4.3009 - mean_absolute_error: 1.3010 - mean_squared_error: 4.3009 - val_loss: 3.4768 - val_mean_absolute_error: 1.3281 - val_mean_squared_error: 3.4768
# Epoch 33/50
#  - 0s - loss: 4.1637 - mean_absolute_error: 1.2747 - mean_squared_error: 4.1637 - val_loss: 3.3356 - val_mean_absolute_error: 1.2812 - val_mean_squared_error: 3.3356
# Epoch 34/50
#  - 0s - loss: 4.0551 - mean_absolute_error: 1.2517 - mean_squared_error: 4.0551 - val_loss: 3.2897 - val_mean_absolute_error: 1.2794 - val_mean_squared_error: 3.2897
# Epoch 35/50
#  - 0s - loss: 3.9497 - mean_absolute_error: 1.2285 - mean_squared_error: 3.9497 - val_loss: 3.1706 - val_mean_absolute_error: 1.2428 - val_mean_squared_error: 3.1706
# Epoch 36/50
#  - 0s - loss: 3.8571 - mean_absolute_error: 1.2124 - mean_squared_error: 3.8571 - val_loss: 3.1982 - val_mean_absolute_error: 1.2424 - val_mean_squared_error: 3.1982
# Epoch 37/50
#  - 0s - loss: 3.7309 - mean_absolute_error: 1.1891 - mean_squared_error: 3.7309 - val_loss: 3.2899 - val_mean_absolute_error: 1.2916 - val_mean_squared_error: 3.2899
# Epoch 38/50
#  - 0s - loss: 3.6839 - mean_absolute_error: 1.1793 - mean_squared_error: 3.6839 - val_loss: 3.0887 - val_mean_absolute_error: 1.2128 - val_mean_squared_error: 3.0887
# Epoch 39/50
#  - 0s - loss: 3.6052 - mean_absolute_error: 1.1653 - mean_squared_error: 3.6052 - val_loss: 3.0454 - val_mean_absolute_error: 1.1937 - val_mean_squared_error: 3.0454
# Epoch 40/50
#  - 0s - loss: 3.4966 - mean_absolute_error: 1.1489 - mean_squared_error: 3.4966 - val_loss: 3.0020 - val_mean_absolute_error: 1.2186 - val_mean_squared_error: 3.0020
# Epoch 41/50
#  - 0s - loss: 3.4255 - mean_absolute_error: 1.1316 - mean_squared_error: 3.4255 - val_loss: 3.1194 - val_mean_absolute_error: 1.2755 - val_mean_squared_error: 3.1194
# Epoch 42/50
#  - 0s - loss: 3.3660 - mean_absolute_error: 1.1267 - mean_squared_error: 3.3660 - val_loss: 2.9470 - val_mean_absolute_error: 1.1814 - val_mean_squared_error: 2.9470
# Epoch 43/50
#  - 0s - loss: 3.2952 - mean_absolute_error: 1.1107 - mean_squared_error: 3.2952 - val_loss: 2.8793 - val_mean_absolute_error: 1.1728 - val_mean_squared_error: 2.8793
# Epoch 44/50
#  - 0s - loss: 3.2330 - mean_absolute_error: 1.1014 - mean_squared_error: 3.2330 - val_loss: 2.8072 - val_mean_absolute_error: 1.1453 - val_mean_squared_error: 2.8072
# Epoch 45/50
#  - 0s - loss: 3.1832 - mean_absolute_error: 1.0895 - mean_squared_error: 3.1832 - val_loss: 2.8086 - val_mean_absolute_error: 1.1372 - val_mean_squared_error: 2.8086
# Epoch 46/50
#  - 0s - loss: 3.1422 - mean_absolute_error: 1.0800 - mean_squared_error: 3.1422 - val_loss: 2.8055 - val_mean_absolute_error: 1.1563 - val_mean_squared_error: 2.8055
# Epoch 47/50
#  - 0s - loss: 3.0447 - mean_absolute_error: 1.0643 - mean_squared_error: 3.0447 - val_loss: 2.7806 - val_mean_absolute_error: 1.1385 - val_mean_squared_error: 2.7806
# Epoch 48/50
#  - 0s - loss: 3.0565 - mean_absolute_error: 1.0568 - mean_squared_error: 3.0565 - val_loss: 2.7892 - val_mean_absolute_error: 1.1556 - val_mean_squared_error: 2.7892
# Epoch 49/50
#  - 0s - loss: 3.0520 - mean_absolute_error: 1.0481 - mean_squared_error: 3.0520 - val_loss: 2.5691 - val_mean_absolute_error: 1.0891 - val_mean_squared_error: 2.5691
# Epoch 50/50
#  - 0s - loss: 3.0307 - mean_absolute_error: 1.0441 - mean_squared_error: 3.0307 - val_loss: 2.5889 - val_mean_absolute_error: 1.1055 - val_mean_squared_error: 2.5889
# CPU times: user 11 s, sys: 3.2 s, total: 14.2 s
# Wall time: 6.98 s

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [MPG]')
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  plt.ylim([0,30])
  plt.legend()
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [$MPG^2$]')
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  plt.ylim([0,40])
  plt.legend()
  plt.show()

plot_history(history_object_A)

# %%
plot_history(history_object_B)

# %%
# Out:
# 0.012274789959436587

# %%
# Out:
# -0.00371287885296025
