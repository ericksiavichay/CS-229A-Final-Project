# %%
#!/usr/bin/env python3
import numpy as np
import math
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from keras.utils import to_categorical
from keras.utils import plot_model
import IPython.display
import matplotlib.pyplot as plt

#if we dont graph it
#import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# Out:
# Using TensorFlow backend.

# %%
#if i want to speed up and use one file
#files2 = "CSVLog_20190518_122417.csv"

#i aggregate the data points for five files into aggregate.csv. i have removed the time predictor from the data set
files = "aggregate_no_time_column.csv"

raw_dataset = pd.read_csv(files, sep=",", skipinitialspace=True)
dataset = raw_dataset.copy()

#remove whitespace in front of column name
dataset.columns = dataset.columns.str.lstrip()

# %%
dataset.tail()
# Out:
#       Absolute load value (%)  Absolute throttle position (%)  \
# 6633                 18.03922                        11.76471
# 6634                 17.64706                        11.76471
# 6635                 17.64706                        11.37255
# 6636                 17.25490                        11.37255
# 6637                 17.64706                        11.37255
#
#       Ambient air temperature (F)  Barometric pressure (inHg)  \
# 6633                         59.0                     29.8254
# 6634                         59.0                     29.8254
# 6635                         59.0                     29.8254
# 6636                         59.0                     29.8254
# 6637                         59.0                     29.8254
#
#       Calculated load value (%)  Commanded fuel rail pressure A (inHg)  \
# 6633                   29.01961                                885.903
# 6634                   29.01961                                885.903
# 6635                   29.41176                                885.903
# 6636                   29.41176                                885.903
# 6637                   29.80392                                885.903
#
#       Engine coolant temperature (F)  Engine RPM (RPM)  Fuel level input (%)  \
# 6633                           183.2            658.75              67.05882
# 6634                           183.2            640.00              67.05882
# 6635                           183.2            607.75              67.05882
# 6636                           183.2            606.75              67.05882
# 6637                           183.2            604.50              67.05882
#
#       Fuel rail pressure (psi)  Fuel/Air commanded equivalence ratio  \
# 6633                  424.9606                              0.994239
# 6634                  449.6170                              0.994239
# 6635                  429.3117                              0.994239
# 6636                  449.6170                              0.994239
# 6637                  429.3117                              0.994239
#
#       Ignition timing advance for #1 cylinder (deg)  \
# 6633                                            5.0
# 6634                                            4.5
# 6635                                            4.0
# 6636                                            6.5
# 6637                                            6.0
#
#       Intake air temperature (F)  Intake manifold absolute pressure (inHg)  \
# 6633                        71.6                                  11.51674
# 6634                        71.6                                  11.51674
# 6635                        71.6                                  11.51674
# 6636                        71.6                                  11.51674
# 6637                        71.6                                  11.51674
#
#       Long term fuel % trim - Bank 1 (%)  Mass air flow rate (lb/min)  \
# 6633                            -0.78125                     0.308259
# 6634                            -0.78125                     0.257985
# 6635                            -0.78125                     0.325458
# 6636                            -0.78125                     0.239463
# 6637                            -0.78125                     0.227556
#
#       Vehicle speed (MPH)  Fuel rate (gal/hr)  Instant fuel economy (MPG)  \
# 6633                  0.0            0.205909                         0.0
# 6634                  0.0            0.172327                         0.0
# 6635                  0.0            0.217398                         0.0
# 6636                  0.0            0.159955                         0.0
# 6637                  0.0            0.152002                         0.0
#
#       Total fuel economy (MPG)
# 6633                  30.11613
# 6634                  30.11534
# 6635                  30.11455
# 6636                  30.11384
# 6637                  30.11316

# %%
# %%time 

#creating data and splitting and random shuffling
#https://stackoverflow.com/questions/38250710/how-to-split-data-into-3-sets-train-validation-and-test/38251213#38251213
def train_validate_test_split(df, train_percent=.6, validate_percent=.2, seed=None):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    train = df.loc[perm[:train_end]]
    validate = df.loc[perm[train_end:validate_end]]
    test = df.loc[perm[validate_end:]]
    return train, validate, test

np.random.seed(1234)
train, validate, test = train_validate_test_split(dataset)

#convert object to float64 first to use panda describe function
#check --> can change to assert
#train = train.apply(lambda col:pd.to_numeric(col, errors='coerce'))
#validate = validate.apply(lambda col:pd.to_numeric(col, errors='coerce'))
#test = test.apply(lambda col:pd.to_numeric(col, errors='coerce'))

train_labels = train.pop("Total fuel economy (MPG)")
validate_labels = validate.pop("Total fuel economy (MPG)")
test_labels = test.pop("Total fuel economy (MPG)")

#train_labels = train_labels.apply(lambda col:pd.to_numeric(col, errors='coerce'))
#validate_labels = validate_labels.apply(lambda col:pd.to_numeric(col, errors='coerce'))
#test_labels = test_labels.apply(lambda col:pd.to_numeric(col, errors='coerce'))

#train.loc[: , "Total fuel economy (MPG)"]
# Out:
# CPU times: user 7.14 ms, sys: 5.97 ms, total: 13.1 ms
# Wall time: 12.6 ms

# %%
train.dtypes
# Out:
# Absolute load value (%)                          float64
# Absolute throttle position (%)                   float64
# Ambient air temperature (F)                      float64
# Barometric pressure (inHg)                       float64
# Calculated load value (%)                        float64
# Commanded fuel rail pressure A (inHg)            float64
# Engine coolant temperature (F)                   float64
# Engine RPM (RPM)                                 float64
# Fuel level input (%)                             float64
# Fuel rail pressure (psi)                         float64
# Fuel/Air commanded equivalence ratio             float64
# Ignition timing advance for #1 cylinder (deg)    float64
# Intake air temperature (F)                       float64
# Intake manifold absolute pressure (inHg)         float64
# Long term fuel % trim - Bank 1 (%)               float64
# Mass air flow rate (lb/min)                      float64
# Vehicle speed (MPH)                              float64
# Fuel rate (gal/hr)                               float64
# Instant fuel economy (MPG)                       float64
# dtype: object

# %%
train = train.apply(lambda col:pd.to_numeric(col, errors='coerce'))
train_stats = train.describe(include = 'all')
#train_stats = train.transpose()
train_stats
# Out:
#        Absolute load value (%)  Absolute throttle position (%)  \
# count              3982.000000                     3982.000000
# mean                 35.181552                       21.504122
# std                  24.512429                       14.032597
# min                   0.000000                        0.000000
# 25%                  16.176470                       12.156860
# 50%                  25.098040                       15.686270
# 75%                  50.588230                       27.058820
# max                  97.647060                       90.980390
#
#        Ambient air temperature (F)  Barometric pressure (inHg)  \
# count                  3982.000000                 3982.000000
# mean                     67.781165                   29.713420
# std                      12.842276                    0.837612
# min                       0.000000                    0.000000
# 25%                      62.600000                   29.530100
# 50%                      62.600000                   29.825400
# 75%                      66.200000                   29.825400
# max                     118.400000                   30.120700
#
#        Calculated load value (%)  Commanded fuel rail pressure A (inHg)  \
# count                3982.000000                            3982.000000
# mean                   42.978107                            1861.275105
# std                    26.423414                            1178.574650
# min                     0.000000                               0.000000
# 25%                    20.784310                             885.903000
# 50%                    38.823530                            1224.022500
# 75%                    57.254900                            2595.696000
# max                   100.000000                            5906.020000
#
#        Engine coolant temperature (F)  Engine RPM (RPM)  Fuel level input (%)  \
# count                     3982.000000       3982.000000           3982.000000
# mean                       185.507032       1520.967793             74.643642
# std                          8.848193        646.856807             11.010374
# min                          0.000000          0.000000              0.000000
# 25%                        183.200000       1076.937500             67.450980
# 50%                        185.000000       1495.125000             74.509800
# 75%                        188.600000       1987.375000             81.176470
# max                        204.800000       4719.500000             93.333340
#
#        Fuel rail pressure (psi)  Fuel/Air commanded equivalence ratio  \
# count               3982.000000                           3982.000000
# mean                 929.879487                              0.980965
# std                  574.998029                              0.038708
# min                    0.000000                              0.000000
# 25%                  478.624500                              0.990335
# 50%                  625.112650                              0.993111
# 75%                 1276.332000                              0.995490
# max                 2987.777000                              1.016260
#
#        Ignition timing advance for #1 cylinder (deg)  \
# count                                    3982.000000
# mean                                       21.228277
# std                                        15.293478
# min                                       -11.000000
# 25%                                         4.500000
# 50%                                        24.000000
# 75%                                        35.500000
# max                                        48.500000
#
#        Intake air temperature (F)  Intake manifold absolute pressure (inHg)  \
# count                 3982.000000                               3982.000000
# mean                    73.527323                                 17.715242
# std                     14.240771                                  8.819556
# min                      0.000000                                  0.000000
# 25%                     64.400000                                 10.114058
# 50%                     68.000000                                 15.355650
# 75%                     77.000000                                 27.167690
# max                    122.000000                                 30.711300
#
#        Long term fuel % trim - Bank 1 (%)  Mass air flow rate (lb/min)  \
# count                         3982.000000                  3982.000000
# mean                             5.438928                     1.513917
# std                              3.910981                     1.588201
# min                             -2.343750                     0.000000
# 25%                              2.343750                     0.317520
# 50%                              6.250000                     0.861934
# 75%                              7.812500                     2.257700
# max                             12.500000                    11.959920
#
#        Vehicle speed (MPH)  Fuel rate (gal/hr)  Instant fuel economy (MPG)
# count          3982.000000         3982.000000                 3982.000000
# mean             31.270170            1.023558                   58.746293
# std              22.617001            1.070164                   74.271818
# min               0.000000            0.000000                    0.000000
# 25%              10.563310            0.212739                   11.012182
# 50%              31.068560            0.582138                   31.612540
# 75%              45.981470            1.520259                   80.388193
# max              76.428660            8.026347                 1252.727000

# %%
#train_stats.loc['mean']

# %%
#https://stackoverflow.com/questions/40758562/can-anyone-explain-me-standardscaler
scaler = StandardScaler()
normed_train = scaler.fit_transform(train)
normed_validate = scaler.fit_transform(validate)
normed_test = scaler.fit_transform(test)

#not technically correct but unsure if its important
#from tf regression website
#Note: Although we intentionally generate these statistics from only the training dataset, 
#these statistics will also be used to normalize the test dataset. We need to do that to project the test 
#dataset into the same distribution that the model has been trained on.

#I normalize it according to the mean an sd of each predictor from each set

# %%
#debugging
#train
#normed_train

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(10, activation=tf.nn.relu, input_shape=[len(train.keys())]),
    layers.Dense(5, activation=tf.nn.relu),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mean_squared_error',
                optimizer=optimizer,
                metrics=['mean_absolute_error', 'mean_squared_error'])
  return model

# %%
# %%time
model = build_model()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 10)                200
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 55
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 261
# Trainable params: 261
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: user 241 ms, sys: 7.29 ms, total: 248 ms
# Wall time: 259 ms

# %%
# %%time
#change batch size?
#try early stop?
# The patience parameter is the amount of epochs to check for improvement
#early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

#history_object = model.fit(train, train_labels, epochs=100, verbose=2,
#         validation_data=(validate, validate_labels), callbacks=[early_stop])

history_object = model.fit(normed_train, train_labels, epochs=100, verbose=2,
         validation_data=(normed_validate, validate_labels))
# Out:
# Train on 3982 samples, validate on 1327 samples
# Epoch 1/100
#  - 0s - loss: 661.0492 - mean_absolute_error: 25.2960 - mean_squared_error: 661.0493 - val_loss: 531.9262 - val_mean_absolute_error: 22.3394 - val_mean_squared_error: 531.9261
# Epoch 2/100
#  - 0s - loss: 393.6644 - mean_absolute_error: 18.5104 - mean_squared_error: 393.6643 - val_loss: 243.6541 - val_mean_absolute_error: 14.0220 - val_mean_squared_error: 243.6542
# Epoch 3/100
#  - 0s - loss: 152.6887 - mean_absolute_error: 10.4725 - mean_squared_error: 152.6887 - val_loss: 82.1553 - val_mean_absolute_error: 7.4071 - val_mean_squared_error: 82.1553
# Epoch 4/100
#  - 0s - loss: 69.1443 - mean_absolute_error: 6.6499 - mean_squared_error: 69.1443 - val_loss: 42.6327 - val_mean_absolute_error: 5.1893 - val_mean_squared_error: 42.6327
# Epoch 5/100
#  - 0s - loss: 38.1065 - mean_absolute_error: 4.6614 - mean_squared_error: 38.1065 - val_loss: 25.5003 - val_mean_absolute_error: 3.8604 - val_mean_squared_error: 25.5003
# Epoch 6/100
#  - 0s - loss: 23.7794 - mean_absolute_error: 3.5140 - mean_squared_error: 23.7794 - val_loss: 19.6137 - val_mean_absolute_error: 3.3764 - val_mean_squared_error: 19.6137
# Epoch 7/100
#  - 0s - loss: 17.6924 - mean_absolute_error: 2.9392 - mean_squared_error: 17.6924 - val_loss: 16.1193 - val_mean_absolute_error: 3.0952 - val_mean_squared_error: 16.1193
# Epoch 8/100
#  - 0s - loss: 14.3881 - mean_absolute_error: 2.6577 - mean_squared_error: 14.3881 - val_loss: 15.3469 - val_mean_absolute_error: 3.0558 - val_mean_squared_error: 15.3469
# Epoch 9/100
#  - 0s - loss: 12.2974 - mean_absolute_error: 2.4547 - mean_squared_error: 12.2974 - val_loss: 13.4269 - val_mean_absolute_error: 2.8903 - val_mean_squared_error: 13.4269
# Epoch 10/100
#  - 0s - loss: 10.6847 - mean_absolute_error: 2.3051 - mean_squared_error: 10.6847 - val_loss: 13.7292 - val_mean_absolute_error: 2.9457 - val_mean_squared_error: 13.7292
# Epoch 11/100
#  - 0s - loss: 9.5610 - mean_absolute_error: 2.2003 - mean_squared_error: 9.5610 - val_loss: 12.9166 - val_mean_absolute_error: 2.8478 - val_mean_squared_error: 12.9166
# Epoch 12/100
#  - 0s - loss: 8.7359 - mean_absolute_error: 2.1179 - mean_squared_error: 8.7359 - val_loss: 12.4011 - val_mean_absolute_error: 2.7814 - val_mean_squared_error: 12.4011
# Epoch 13/100
#  - 0s - loss: 8.0768 - mean_absolute_error: 2.0412 - mean_squared_error: 8.0768 - val_loss: 12.0875 - val_mean_absolute_error: 2.7620 - val_mean_squared_error: 12.0875
# Epoch 14/100
#  - 0s - loss: 7.6411 - mean_absolute_error: 1.9875 - mean_squared_error: 7.6411 - val_loss: 11.7353 - val_mean_absolute_error: 2.7075 - val_mean_squared_error: 11.7353
# Epoch 15/100
#  - 0s - loss: 7.2506 - mean_absolute_error: 1.9273 - mean_squared_error: 7.2506 - val_loss: 11.0614 - val_mean_absolute_error: 2.6308 - val_mean_squared_error: 11.0614
# Epoch 16/100
#  - 0s - loss: 6.9262 - mean_absolute_error: 1.8913 - mean_squared_error: 6.9262 - val_loss: 10.7876 - val_mean_absolute_error: 2.6067 - val_mean_squared_error: 10.7876
# Epoch 17/100
#  - 0s - loss: 6.5823 - mean_absolute_error: 1.8514 - mean_squared_error: 6.5823 - val_loss: 10.6297 - val_mean_absolute_error: 2.5795 - val_mean_squared_error: 10.6297
# Epoch 18/100
#  - 0s - loss: 6.2863 - mean_absolute_error: 1.8153 - mean_squared_error: 6.2863 - val_loss: 10.1523 - val_mean_absolute_error: 2.5336 - val_mean_squared_error: 10.1523
# Epoch 19/100
#  - 0s - loss: 6.0219 - mean_absolute_error: 1.7825 - mean_squared_error: 6.0219 - val_loss: 10.4086 - val_mean_absolute_error: 2.5492 - val_mean_squared_error: 10.4086
# Epoch 20/100
#  - 0s - loss: 5.8566 - mean_absolute_error: 1.7584 - mean_squared_error: 5.8566 - val_loss: 9.8490 - val_mean_absolute_error: 2.4873 - val_mean_squared_error: 9.8490
# Epoch 21/100
#  - 0s - loss: 5.6641 - mean_absolute_error: 1.7309 - mean_squared_error: 5.6641 - val_loss: 9.5496 - val_mean_absolute_error: 2.4349 - val_mean_squared_error: 9.5496
# Epoch 22/100
#  - 0s - loss: 5.4790 - mean_absolute_error: 1.7091 - mean_squared_error: 5.4790 - val_loss: 9.5815 - val_mean_absolute_error: 2.4300 - val_mean_squared_error: 9.5815
# Epoch 23/100
#  - 0s - loss: 5.3738 - mean_absolute_error: 1.6940 - mean_squared_error: 5.3738 - val_loss: 9.6930 - val_mean_absolute_error: 2.4595 - val_mean_squared_error: 9.6930
# Epoch 24/100
#  - 0s - loss: 5.2478 - mean_absolute_error: 1.6729 - mean_squared_error: 5.2478 - val_loss: 9.4432 - val_mean_absolute_error: 2.4291 - val_mean_squared_error: 9.4432
# Epoch 25/100
#  - 0s - loss: 5.1149 - mean_absolute_error: 1.6596 - mean_squared_error: 5.1149 - val_loss: 9.1667 - val_mean_absolute_error: 2.3779 - val_mean_squared_error: 9.1667
# Epoch 26/100
#  - 0s - loss: 5.0138 - mean_absolute_error: 1.6473 - mean_squared_error: 5.0138 - val_loss: 9.9168 - val_mean_absolute_error: 2.4590 - val_mean_squared_error: 9.9168
# Epoch 27/100
#  - 0s - loss: 4.9362 - mean_absolute_error: 1.6340 - mean_squared_error: 4.9362 - val_loss: 9.7203 - val_mean_absolute_error: 2.4425 - val_mean_squared_error: 9.7203
# Epoch 28/100
#  - 0s - loss: 4.8571 - mean_absolute_error: 1.6217 - mean_squared_error: 4.8571 - val_loss: 8.4482 - val_mean_absolute_error: 2.2843 - val_mean_squared_error: 8.4482
# Epoch 29/100
#  - 0s - loss: 4.7725 - mean_absolute_error: 1.6189 - mean_squared_error: 4.7725 - val_loss: 8.6754 - val_mean_absolute_error: 2.3275 - val_mean_squared_error: 8.6754
# Epoch 30/100
#  - 0s - loss: 4.6983 - mean_absolute_error: 1.6055 - mean_squared_error: 4.6983 - val_loss: 8.9106 - val_mean_absolute_error: 2.3561 - val_mean_squared_error: 8.9106
# Epoch 31/100
#  - 0s - loss: 4.6235 - mean_absolute_error: 1.5958 - mean_squared_error: 4.6235 - val_loss: 8.6162 - val_mean_absolute_error: 2.3226 - val_mean_squared_error: 8.6162
# Epoch 32/100
#  - 0s - loss: 4.5571 - mean_absolute_error: 1.5834 - mean_squared_error: 4.5571 - val_loss: 10.0109 - val_mean_absolute_error: 2.4713 - val_mean_squared_error: 10.0109
# Epoch 33/100
#  - 0s - loss: 4.5571 - mean_absolute_error: 1.5741 - mean_squared_error: 4.5571 - val_loss: 8.8598 - val_mean_absolute_error: 2.3345 - val_mean_squared_error: 8.8598
# Epoch 34/100
#  - 0s - loss: 4.4731 - mean_absolute_error: 1.5674 - mean_squared_error: 4.4731 - val_loss: 8.4346 - val_mean_absolute_error: 2.2752 - val_mean_squared_error: 8.4346
# Epoch 35/100
#  - 0s - loss: 4.4445 - mean_absolute_error: 1.5625 - mean_squared_error: 4.4445 - val_loss: 9.3799 - val_mean_absolute_error: 2.3890 - val_mean_squared_error: 9.3799
# Epoch 36/100
#  - 0s - loss: 4.3945 - mean_absolute_error: 1.5484 - mean_squared_error: 4.3945 - val_loss: 8.5726 - val_mean_absolute_error: 2.2896 - val_mean_squared_error: 8.5726
# Epoch 37/100
#  - 0s - loss: 4.3569 - mean_absolute_error: 1.5464 - mean_squared_error: 4.3569 - val_loss: 7.6390 - val_mean_absolute_error: 2.1855 - val_mean_squared_error: 7.6390
# Epoch 38/100
#  - 0s - loss: 4.3049 - mean_absolute_error: 1.5484 - mean_squared_error: 4.3049 - val_loss: 8.5103 - val_mean_absolute_error: 2.2996 - val_mean_squared_error: 8.5103
# Epoch 39/100
#  - 0s - loss: 4.2688 - mean_absolute_error: 1.5408 - mean_squared_error: 4.2688 - val_loss: 9.0569 - val_mean_absolute_error: 2.3499 - val_mean_squared_error: 9.0569
# Epoch 40/100
#  - 0s - loss: 4.2200 - mean_absolute_error: 1.5335 - mean_squared_error: 4.2200 - val_loss: 9.5474 - val_mean_absolute_error: 2.4053 - val_mean_squared_error: 9.5474
# Epoch 41/100
#  - 0s - loss: 4.2020 - mean_absolute_error: 1.5347 - mean_squared_error: 4.2020 - val_loss: 9.1967 - val_mean_absolute_error: 2.3799 - val_mean_squared_error: 9.1967
# Epoch 42/100
#  - 0s - loss: 4.1749 - mean_absolute_error: 1.5292 - mean_squared_error: 4.1749 - val_loss: 8.4974 - val_mean_absolute_error: 2.2825 - val_mean_squared_error: 8.4974
# Epoch 43/100
#  - 0s - loss: 4.1111 - mean_absolute_error: 1.5219 - mean_squared_error: 4.1111 - val_loss: 8.6920 - val_mean_absolute_error: 2.3234 - val_mean_squared_error: 8.6920
# Epoch 44/100
#  - 0s - loss: 4.1333 - mean_absolute_error: 1.5197 - mean_squared_error: 4.1333 - val_loss: 8.0489 - val_mean_absolute_error: 2.2483 - val_mean_squared_error: 8.0489
# Epoch 45/100
#  - 0s - loss: 4.1533 - mean_absolute_error: 1.5208 - mean_squared_error: 4.1533 - val_loss: 8.1273 - val_mean_absolute_error: 2.2435 - val_mean_squared_error: 8.1273
# Epoch 46/100
#  - 0s - loss: 4.0763 - mean_absolute_error: 1.5171 - mean_squared_error: 4.0763 - val_loss: 8.1945 - val_mean_absolute_error: 2.2507 - val_mean_squared_error: 8.1945
# Epoch 47/100
#  - 0s - loss: 4.0768 - mean_absolute_error: 1.5089 - mean_squared_error: 4.0768 - val_loss: 8.1243 - val_mean_absolute_error: 2.2527 - val_mean_squared_error: 8.1243
# Epoch 48/100
#  - 0s - loss: 4.0655 - mean_absolute_error: 1.5141 - mean_squared_error: 4.0655 - val_loss: 8.1695 - val_mean_absolute_error: 2.2363 - val_mean_squared_error: 8.1695
# Epoch 49/100
#  - 0s - loss: 4.0244 - mean_absolute_error: 1.5037 - mean_squared_error: 4.0244 - val_loss: 8.7306 - val_mean_absolute_error: 2.3070 - val_mean_squared_error: 8.7306
# Epoch 50/100
#  - 0s - loss: 4.0516 - mean_absolute_error: 1.5105 - mean_squared_error: 4.0516 - val_loss: 8.5484 - val_mean_absolute_error: 2.2864 - val_mean_squared_error: 8.5484
# Epoch 51/100
#  - 0s - loss: 4.0279 - mean_absolute_error: 1.5055 - mean_squared_error: 4.0279 - val_loss: 8.1299 - val_mean_absolute_error: 2.2454 - val_mean_squared_error: 8.1299
# Epoch 52/100
#  - 0s - loss: 4.0080 - mean_absolute_error: 1.5009 - mean_squared_error: 4.0080 - val_loss: 7.8524 - val_mean_absolute_error: 2.2178 - val_mean_squared_error: 7.8524
# Epoch 53/100
#  - 0s - loss: 3.9696 - mean_absolute_error: 1.5023 - mean_squared_error: 3.9696 - val_loss: 7.8102 - val_mean_absolute_error: 2.1939 - val_mean_squared_error: 7.8102
# Epoch 54/100
#  - 0s - loss: 3.9588 - mean_absolute_error: 1.4931 - mean_squared_error: 3.9588 - val_loss: 8.0822 - val_mean_absolute_error: 2.2281 - val_mean_squared_error: 8.0822
# Epoch 55/100
#  - 0s - loss: 3.9242 - mean_absolute_error: 1.4920 - mean_squared_error: 3.9242 - val_loss: 8.6440 - val_mean_absolute_error: 2.2941 - val_mean_squared_error: 8.6440
# Epoch 56/100
#  - 0s - loss: 3.9334 - mean_absolute_error: 1.4882 - mean_squared_error: 3.9334 - val_loss: 8.2066 - val_mean_absolute_error: 2.2628 - val_mean_squared_error: 8.2066
# Epoch 57/100
#  - 0s - loss: 3.9257 - mean_absolute_error: 1.4945 - mean_squared_error: 3.9257 - val_loss: 8.2604 - val_mean_absolute_error: 2.2428 - val_mean_squared_error: 8.2604
# Epoch 58/100
#  - 0s - loss: 3.9122 - mean_absolute_error: 1.4843 - mean_squared_error: 3.9122 - val_loss: 7.8301 - val_mean_absolute_error: 2.2115 - val_mean_squared_error: 7.8301
# Epoch 59/100
#  - 0s - loss: 3.9164 - mean_absolute_error: 1.4844 - mean_squared_error: 3.9164 - val_loss: 8.1067 - val_mean_absolute_error: 2.2328 - val_mean_squared_error: 8.1067
# Epoch 60/100
#  - 0s - loss: 3.9112 - mean_absolute_error: 1.4931 - mean_squared_error: 3.9112 - val_loss: 7.6083 - val_mean_absolute_error: 2.1820 - val_mean_squared_error: 7.6083
# Epoch 61/100
#  - 0s - loss: 3.8907 - mean_absolute_error: 1.4854 - mean_squared_error: 3.8907 - val_loss: 7.8594 - val_mean_absolute_error: 2.1949 - val_mean_squared_error: 7.8594
# Epoch 62/100
#  - 0s - loss: 3.8631 - mean_absolute_error: 1.4820 - mean_squared_error: 3.8631 - val_loss: 8.2497 - val_mean_absolute_error: 2.2483 - val_mean_squared_error: 8.2497
# Epoch 63/100
#  - 0s - loss: 3.8597 - mean_absolute_error: 1.4827 - mean_squared_error: 3.8597 - val_loss: 7.3832 - val_mean_absolute_error: 2.1578 - val_mean_squared_error: 7.3832
# Epoch 64/100
#  - 0s - loss: 3.8511 - mean_absolute_error: 1.4786 - mean_squared_error: 3.8511 - val_loss: 7.6110 - val_mean_absolute_error: 2.1529 - val_mean_squared_error: 7.6110
# Epoch 65/100
#  - 0s - loss: 3.8563 - mean_absolute_error: 1.4814 - mean_squared_error: 3.8563 - val_loss: 7.7316 - val_mean_absolute_error: 2.1896 - val_mean_squared_error: 7.7316
# Epoch 66/100
#  - 0s - loss: 3.8531 - mean_absolute_error: 1.4802 - mean_squared_error: 3.8531 - val_loss: 8.0796 - val_mean_absolute_error: 2.2348 - val_mean_squared_error: 8.0796
# Epoch 67/100
#  - 0s - loss: 3.8809 - mean_absolute_error: 1.4858 - mean_squared_error: 3.8809 - val_loss: 8.2834 - val_mean_absolute_error: 2.2508 - val_mean_squared_error: 8.2834
# Epoch 68/100
#  - 0s - loss: 3.8324 - mean_absolute_error: 1.4786 - mean_squared_error: 3.8324 - val_loss: 7.9413 - val_mean_absolute_error: 2.1930 - val_mean_squared_error: 7.9413
# Epoch 69/100
#  - 0s - loss: 3.8152 - mean_absolute_error: 1.4704 - mean_squared_error: 3.8152 - val_loss: 8.5578 - val_mean_absolute_error: 2.2661 - val_mean_squared_error: 8.5578
# Epoch 70/100
#  - 0s - loss: 3.8004 - mean_absolute_error: 1.4666 - mean_squared_error: 3.8004 - val_loss: 7.6357 - val_mean_absolute_error: 2.1883 - val_mean_squared_error: 7.6357
# Epoch 71/100
#  - 0s - loss: 3.8346 - mean_absolute_error: 1.4738 - mean_squared_error: 3.8346 - val_loss: 7.9551 - val_mean_absolute_error: 2.2182 - val_mean_squared_error: 7.9551
# Epoch 72/100
#  - 0s - loss: 3.8634 - mean_absolute_error: 1.4727 - mean_squared_error: 3.8634 - val_loss: 7.4952 - val_mean_absolute_error: 2.1541 - val_mean_squared_error: 7.4952
# Epoch 73/100
#  - 0s - loss: 3.7949 - mean_absolute_error: 1.4634 - mean_squared_error: 3.7949 - val_loss: 7.6998 - val_mean_absolute_error: 2.1946 - val_mean_squared_error: 7.6998
# Epoch 74/100
#  - 0s - loss: 3.7817 - mean_absolute_error: 1.4687 - mean_squared_error: 3.7817 - val_loss: 7.9371 - val_mean_absolute_error: 2.2198 - val_mean_squared_error: 7.9371
# Epoch 75/100
#  - 0s - loss: 3.8085 - mean_absolute_error: 1.4679 - mean_squared_error: 3.8085 - val_loss: 7.5894 - val_mean_absolute_error: 2.1718 - val_mean_squared_error: 7.5894
# Epoch 76/100
#  - 0s - loss: 3.7714 - mean_absolute_error: 1.4637 - mean_squared_error: 3.7714 - val_loss: 8.0048 - val_mean_absolute_error: 2.2174 - val_mean_squared_error: 8.0048
# Epoch 77/100
#  - 0s - loss: 3.8149 - mean_absolute_error: 1.4619 - mean_squared_error: 3.8149 - val_loss: 7.8433 - val_mean_absolute_error: 2.1921 - val_mean_squared_error: 7.8433
# Epoch 78/100
#  - 0s - loss: 3.8111 - mean_absolute_error: 1.4640 - mean_squared_error: 3.8111 - val_loss: 7.4130 - val_mean_absolute_error: 2.1434 - val_mean_squared_error: 7.4130
# Epoch 79/100
#  - 0s - loss: 3.7891 - mean_absolute_error: 1.4605 - mean_squared_error: 3.7891 - val_loss: 8.6880 - val_mean_absolute_error: 2.2941 - val_mean_squared_error: 8.6880
# Epoch 80/100
#  - 0s - loss: 3.7664 - mean_absolute_error: 1.4582 - mean_squared_error: 3.7664 - val_loss: 7.4754 - val_mean_absolute_error: 2.1433 - val_mean_squared_error: 7.4754
# Epoch 81/100
#  - 0s - loss: 3.7582 - mean_absolute_error: 1.4682 - mean_squared_error: 3.7582 - val_loss: 8.4976 - val_mean_absolute_error: 2.2745 - val_mean_squared_error: 8.4976
# Epoch 82/100
#  - 0s - loss: 3.7853 - mean_absolute_error: 1.4551 - mean_squared_error: 3.7853 - val_loss: 7.6957 - val_mean_absolute_error: 2.1899 - val_mean_squared_error: 7.6957
# Epoch 83/100
#  - 0s - loss: 3.7481 - mean_absolute_error: 1.4629 - mean_squared_error: 3.7481 - val_loss: 8.0264 - val_mean_absolute_error: 2.2226 - val_mean_squared_error: 8.0264
# Epoch 84/100
#  - 0s - loss: 3.7549 - mean_absolute_error: 1.4573 - mean_squared_error: 3.7549 - val_loss: 8.1777 - val_mean_absolute_error: 2.2401 - val_mean_squared_error: 8.1777
# Epoch 85/100
#  - 0s - loss: 3.7606 - mean_absolute_error: 1.4589 - mean_squared_error: 3.7606 - val_loss: 7.6746 - val_mean_absolute_error: 2.1759 - val_mean_squared_error: 7.6746
# Epoch 86/100
#  - 0s - loss: 3.7617 - mean_absolute_error: 1.4626 - mean_squared_error: 3.7617 - val_loss: 7.8375 - val_mean_absolute_error: 2.1940 - val_mean_squared_error: 7.8375
# Epoch 87/100
#  - 0s - loss: 3.7612 - mean_absolute_error: 1.4504 - mean_squared_error: 3.7612 - val_loss: 8.0933 - val_mean_absolute_error: 2.2220 - val_mean_squared_error: 8.0933
# Epoch 88/100
#  - 0s - loss: 3.7656 - mean_absolute_error: 1.4552 - mean_squared_error: 3.7656 - val_loss: 8.1839 - val_mean_absolute_error: 2.2428 - val_mean_squared_error: 8.1839
# Epoch 89/100
#  - 0s - loss: 3.7213 - mean_absolute_error: 1.4561 - mean_squared_error: 3.7213 - val_loss: 8.2597 - val_mean_absolute_error: 2.2473 - val_mean_squared_error: 8.2597
# Epoch 90/100
#  - 0s - loss: 3.6973 - mean_absolute_error: 1.4529 - mean_squared_error: 3.6973 - val_loss: 7.2450 - val_mean_absolute_error: 2.1255 - val_mean_squared_error: 7.2450
# Epoch 91/100
#  - 0s - loss: 3.7337 - mean_absolute_error: 1.4491 - mean_squared_error: 3.7337 - val_loss: 7.5582 - val_mean_absolute_error: 2.1644 - val_mean_squared_error: 7.5582
# Epoch 92/100
#  - 0s - loss: 3.7005 - mean_absolute_error: 1.4553 - mean_squared_error: 3.7005 - val_loss: 7.8073 - val_mean_absolute_error: 2.1978 - val_mean_squared_error: 7.8073
# Epoch 93/100
#  - 0s - loss: 3.6983 - mean_absolute_error: 1.4481 - mean_squared_error: 3.6983 - val_loss: 7.3500 - val_mean_absolute_error: 2.1275 - val_mean_squared_error: 7.3500
# Epoch 94/100
#  - 0s - loss: 3.6792 - mean_absolute_error: 1.4470 - mean_squared_error: 3.6792 - val_loss: 7.4079 - val_mean_absolute_error: 2.1514 - val_mean_squared_error: 7.4079
# Epoch 95/100
#  - 0s - loss: 3.7061 - mean_absolute_error: 1.4514 - mean_squared_error: 3.7061 - val_loss: 7.0640 - val_mean_absolute_error: 2.1225 - val_mean_squared_error: 7.0640
# Epoch 96/100
#  - 0s - loss: 3.7279 - mean_absolute_error: 1.4411 - mean_squared_error: 3.7278 - val_loss: 7.1067 - val_mean_absolute_error: 2.1091 - val_mean_squared_error: 7.1067
# Epoch 97/100
#  - 0s - loss: 3.7033 - mean_absolute_error: 1.4413 - mean_squared_error: 3.7033 - val_loss: 7.2783 - val_mean_absolute_error: 2.1508 - val_mean_squared_error: 7.2783
# Epoch 98/100
#  - 0s - loss: 3.6981 - mean_absolute_error: 1.4458 - mean_squared_error: 3.6981 - val_loss: 6.9495 - val_mean_absolute_error: 2.0903 - val_mean_squared_error: 6.9495
# Epoch 99/100
#  - 0s - loss: 3.6901 - mean_absolute_error: 1.4464 - mean_squared_error: 3.6901 - val_loss: 7.3180 - val_mean_absolute_error: 2.1237 - val_mean_squared_error: 7.3180
# Epoch 100/100
#  - 0s - loss: 3.6850 - mean_absolute_error: 1.4423 - mean_squared_error: 3.6850 - val_loss: 7.4581 - val_mean_absolute_error: 2.1717 - val_mean_squared_error: 7.4581
# CPU times: user 26 s, sys: 8.12 s, total: 34.1 s
# Wall time: 16.4 s

# %%
#history_object.history

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [MPG]')
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  plt.ylim([0,10])
  plt.legend()
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [$MPG^2$]')
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  plt.ylim([0,20])
  plt.legend()
  plt.show()


plot_history(history_object)

# %%
#loss, mae, mse = model.evaluate(test, test_labels, verbose=2)
normed_test[:10]
# Out:
# array([[-1.00731502, -0.76367379,  0.65647356,  0.45685647, -1.09169362,
#         -0.81544774,  0.19588437, -0.71306086,  0.32480709, -0.81261084,
#          0.57082083,  0.90431469,  0.57226282, -1.31564181,  0.02040704,
#         -0.78839515, -0.3600188 , -0.79341099,  1.00572175],
#        [ 0.77812791,  0.5932145 ,  0.65647356,  2.02170763,  0.80540775,
#          1.57299574,  0.46152756,  0.9816488 ,  1.74070791,  1.92081389,
#          0.35189368, -1.15208719,  0.16800841,  1.16548123,  0.6230951 ,
#          1.0566561 ,  0.07733469,  1.03578847, -0.56498275],
#        [-1.00731502, -0.73352048, -0.70437223,  0.45685647, -1.12180619,
#         -0.81544774, -0.6010452 , -0.50344506, -1.30892448, -0.77949388,
#          0.57082083,  0.90431469, -0.64050039, -1.3826992 , -1.98855314,
#         -0.78255374, -0.60603008, -0.78764965,  0.53921506],
#        [ 0.76174757,  0.89474532, -0.40196206, -1.10799469,  0.65484411,
#          0.82629358, -0.33540201,  0.73646643, -0.65543222,  0.70058044,
#          0.27891258,  0.10828816, -0.64050039,  1.29959669,  0.22130306,
#          0.57766043,  1.60807189,  0.56588378, -0.25899004],
#        [ 1.13849248,  0.1710712 , -0.40196206,  0.45685647,  0.73012574,
#          0.62264715, -0.33540201, -0.07891632, -0.32868609,  0.42290761,
#          0.4189574 , -0.22338956, -0.37099746,  0.89725257,  0.6230951 ,
#          0.56597761, -0.52402602,  0.55133734, -0.60423852],
#        [-0.74523166, -0.31137718, -0.40196206,  0.45685647, -0.95618646,
#         -0.69979716, -0.06975882,  2.01572818,  1.74070791, -0.75401924,
#          0.40416393,  1.60083791, -0.37099746, -0.94682615, -0.18048897,
#         -0.18255743,  0.35068095, -0.19233298, -0.17431346],
#        [-0.31934614,  0.11076535, -0.40196206,  0.45685647, -0.39910096,
#          0.10221785, -0.06975882,  2.64192699,  1.74070791,  0.14268622,
#         -2.52888749,  0.5394692 , -0.23624599,  0.02550603, -0.18048897,
#          0.71284737,  0.62402677,  0.68724246, -0.44352897],
#        [-0.04088286, -0.16061216,  2.31972952,  0.45685647, -0.09797407,
#         -0.26987701,  0.99281394,  0.18896813, -1.63567154, -0.4050173 ,
#          0.21382132,  1.50133459,  1.65027456, -0.3768381 ,  0.6230951 ,
#         -0.04820498,  0.07733469, -0.05635181, -0.3385401 ],
#        [ 1.15487241,  0.50275533, -0.25075697,  0.45685647,  0.95597101,
#          0.98971287,  0.99281394,  0.40615128, -0.98217835,  0.81521614,
#          0.32329298, -0.09071847,  0.03325695,  1.09842407, -0.18048897,
#          0.90978635, -0.71536823,  0.89947307, -0.65690308],
#        [ 2.28510714,  1.64857198, -0.25075697, -1.10799469,  2.00991608,
#          2.20153404, -0.06975882,  2.11713076, -0.87326298,  2.12970566,
#          0.24636695, -0.95308055, -0.64050039,  1.19900981,  1.82847121,
#          2.86916235, -0.27801474,  2.85096689, -0.67550978]])

# %%
example_batch = normed_test[:10]
example_result = model.predict(example_batch)
example_result
# Out:
# array([[29.608942],
#        [36.57424 ],
#        [29.134825],
#        [23.79917 ],
#        [28.98628 ],
#        [29.568262],
#        [28.201414],
#        [31.451124],
#        [33.63095 ],
#        [25.246422]], dtype=float32)
